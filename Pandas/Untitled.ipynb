# %%
import pandas as pd

# %%
df = pd.read_csv('players_21.csv')

# %%
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     200389  https://sofifa.com/player/200389/jan-oblak/210002
# 3     188545  https://sofifa.com/player/188545/robert-lewand...
# 4     190871  https://sofifa.com/player/190871/neymar-da-sil...
#
#                 Name                        Complete Name  Age       D.O.B  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   33  24-06-1987
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   35  05-02-1985
# 2           J. Oblak                            Jan Oblak   27  07-01-1993
# 3     R. Lewandowski                   Robert Lewandowski   31  21-08-1988
# 4          Neymar Jr        Neymar da Silva Santos Júnior   28  05-02-1992
#
#    Height (in cm)  Weight (in kg) Nationality            Club Name  ...   lwb  \
# ...

# %%
df.tail()
# Out:
#        sofifa_id                                         player_url  \
# 18939     256679  https://sofifa.com/player/256679/kevin-angulo/...
# 18940     257710  https://sofifa.com/player/257710/mengxuan-zhan...
# 18941     250989  https://sofifa.com/player/250989/zhenghao-wang...
# 18942     257697  https://sofifa.com/player/257697/zitong-chen/2...
# 18943     257936   https://sofifa.com/player/257936/yue-song/210002
#
#                  Name   Complete Name  Age       D.O.B  Height (in cm)  \
# 18939       K. Angulo    Kevin Angulo   24  13-04-1996             176
# 18940  Zhang Mengxuan  Mengxuan Zhang   21  26-04-1999             177
# 18941   Wang Zhenghao             王政豪   20  28-06-2000             185
# 18942     Chen Zitong     Zitong Chen   23  20-02-1997             186
# 18943        Song Yue        Yue Song   28  20-11-1991             185
#
#        Weight (in kg) Nationality                            Club Name  ...  \
# ...

# %%
df.columns
# Out:
# Index(['sofifa_id', 'player_url', 'Name', 'Complete Name', 'Age', 'D.O.B',
#        'Height (in cm)', 'Weight (in kg)', 'Nationality', 'Club Name',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=105)

# %%
df.describe()
# Out:
#            sofifa_id           Age  Height (in cm)  Weight (in kg)  \
# count   18944.000000  18944.000000    18944.000000    18944.000000
# mean   226242.402872     25.225823      181.190773       75.016892
# std     27171.091056      4.697354        6.825672        7.057140
# min        41.000000     16.000000      155.000000       50.000000
# 25%    210030.500000     21.000000      176.000000       70.000000
# 50%    232314.500000     25.000000      181.000000       75.000000
# 75%    246760.250000     29.000000      186.000000       80.000000
# max    258970.000000     53.000000      206.000000      110.000000
#
#         League Rank       Overall     Potetnial         Value           Wage  \
# count  18719.000000  18944.000000  18944.000000  1.894400e+04   18944.000000
# mean       1.357070     65.677787     71.086729  2.224813e+06    8675.852513
# std        0.739327      7.002278      6.109985  5.102486e+06   19654.774894
# ...

# %%
df['Name'][0:5]
# Out:
# 0             L. Messi
# 1    Cristiano Ronaldo
# 2             J. Oblak
# 3       R. Lewandowski
# 4            Neymar Jr
# Name: Name, dtype: object

# %%
df.iloc[0,1]
# Out:
# 'https://sofifa.com/player/158023/lionel-messi/210002'

# %%
df.loc[df['Club Name'] == 'Real Madrid']
# Out:
#        sofifa_id                                         player_url  \
# 12        192119  https://sofifa.com/player/192119/thibaut-court...
# 14        155862  https://sofifa.com/player/155862/sergio-ramos-...
# 15        165153  https://sofifa.com/player/165153/karim-benzema...
# 17        200145  https://sofifa.com/player/200145/carlos-henriq...
# 24        182521  https://sofifa.com/player/182521/toni-kroos/21...
# 25        183277  https://sofifa.com/player/183277/eden-hazard/2...
# 38        177003  https://sofifa.com/player/177003/luka-modric/2...
# 48        201535  https://sofifa.com/player/201535/raphael-varan...
# 60        204963  https://sofifa.com/player/204963/daniel-carvaj...
# 133       197781  https://sofifa.com/player/197781/francisco-rom...
# 140       239053  https://sofifa.com/player/239053/federico-valv...
# 141       222665  https://sofifa.com/player/222665/martin-odegaa...
# 148       228618  https://sofifa.com/player/228618/ferland-mendy...
# ...

# %%
a = df.sort_values('Name')
a.head()
# Out:
#        sofifa_id                                         player_url  \
# 15058     237347  https://sofifa.com/player/237347/abdel-hakim-a...
# 12643     243896  https://sofifa.com/player/243896/ayoub-abdella...
# 8982      252711   https://sofifa.com/player/252711/ali-abdi/210002
# 12363     245438  https://sofifa.com/player/245438/ahmed-abdu/21...
# 17681     243092  https://sofifa.com/player/243092/abduhamit-abd...
#
#                 Name         Complete Name  Age       D.O.B  Height (in cm)  \
# 15058    A. Abdallah  Abdel Hakim Abdallah   22  18-08-1997             170
# 12643  A. Abdellaoui      Ayoub Abdellaoui   27  16-02-1993             183
# 8982         A. Abdi              Ali Abdi   26  20-12-1993             183
# 12363        A. Abdu     Ahmed Abdoh Jaber   23  08-08-1996             177
# 17681   A. Abdugheni          阿不都海米提·阿不都格尼   22  10-03-1998             185
#
#        Weight (in kg)   Nationality          Club Name  ...   lwb   ldm   cdm  \
# ...

# %%
df.sort_values(['Name', 'Height (in cm)'])
# Out:
#        sofifa_id                                         player_url  \
# 15058     237347  https://sofifa.com/player/237347/abdel-hakim-a...
# 12643     243896  https://sofifa.com/player/243896/ayoub-abdella...
# 8982      252711   https://sofifa.com/player/252711/ali-abdi/210002
# 12363     245438  https://sofifa.com/player/245438/ahmed-abdu/21...
# 17681     243092  https://sofifa.com/player/243092/abduhamit-abd...
# ...          ...                                                ...
# 17114     258364  https://sofifa.com/player/258364/stefan-bodist...
# 793       165109  https://sofifa.com/player/165109/stefan-radu/2...
# 17600     248421  https://sofifa.com/player/248421/stefan-rusu/2...
# 13994     248073  https://sofifa.com/player/248073/stefan-tarnov...
# 8659      247949  https://sofifa.com/player/247949/stefan-vladoi...
#
#                 Name           Complete Name  Age       D.O.B  Height (in cm)  \
# ...

# %%
df['Total'] = df['Potetnial']+df['Overall']+df['international_reputation']+df['Weak_foot']+df['Skill move']+df['pace']+df['passing']+df['shooting']+df['dribbling']+df['defending']+df['physic']
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     200389  https://sofifa.com/player/200389/jan-oblak/210002
# 3     188545  https://sofifa.com/player/188545/robert-lewand...
# 4     190871  https://sofifa.com/player/190871/neymar-da-sil...
#
#                 Name                        Complete Name  Age       D.O.B  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   33  24-06-1987
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   35  05-02-1985
# 2           J. Oblak                            Jan Oblak   27  07-01-1993
# 3     R. Lewandowski                   Robert Lewandowski   31  21-08-1988
# 4          Neymar Jr        Neymar da Silva Santos Júnior   28  05-02-1992
#
#    Height (in cm)  Weight (in kg) Nationality            Club Name  ...   ldm  \
# ...

# %%
df.groupby(['Nationality']).count()
# Out:
#              sofifa_id  player_url  Name  Complete Name  Age  D.O.B  \
# Nationality
# Afghanistan          2           2     2              2    2      2
# Albania             49          49    49             49   49     49
# Algeria             52          52    52             52   52     52
# Andorra              1           1     1              1    1      1
# Angola              16          16    16             16   16     16
# ...                ...         ...   ...            ...  ...    ...
# Uzbekistan           7           7     7              7    7      7
# Venezuela          198         198   198            198  198    198
# Wales              124         124   124            124  124    124
# Zambia              11          11    11             11   11     11
# Zimbabwe            11          11    11             11   11     11
#
#              Height (in cm)  Weight (in kg)  Club Name  League Name  ...  ldm  \
# ...

# %%
df.loc[(df['Nationality'] == 'Spain') & (df['Club Name'] == 'Real Madrid')]
# Out:
#        sofifa_id                                         player_url  \
# 14        155862  https://sofifa.com/player/155862/sergio-ramos-...
# 60        204963  https://sofifa.com/player/204963/daniel-carvaj...
# 133       197781  https://sofifa.com/player/197781/francisco-rom...
# 220       220834  https://sofifa.com/player/220834/marco-asensio...
# 479       200724  https://sofifa.com/player/200724/jose-ignacio-...
# 485       208618  https://sofifa.com/player/208618/lucas-vazquez...
# 562       234035  https://sofifa.com/player/234035/alvaro-odrioz...
# 1219      228635  https://sofifa.com/player/228635/borja-mayoral...
# 6374      244523  https://sofifa.com/player/244523/javier-hernan...
# 6378      246787  https://sofifa.com/player/246787/hugo-vallejo-...
# 6391      243032  https://sofifa.com/player/243032/hugo-duro-per...
# 6397      258922  https://sofifa.com/player/258922/marvin-olawal...
# 11029     254008  https://sofifa.com/player/254008/javier-belman...
# ...
